# %%
import sqlite3

conn = sqlite3.connect("../data/vivino.db")
cursor = conn.cursor()

with open("../queries/test_queries.sql", "r") as f:
    query = f.read()

cursor.execute(query)
cursor.fetchall()
# Out:
# [(1964, 4.7),
#  (1962, 4.7),
#  (1929, 4.7),
#  (1961, 4.65),
#  (1955, 4.65),
#  (1979, 4.63),
#  (1976, 4.63),
#  (1970, 4.63),
#  (1987, 4.6),
#  (1981, 4.6)]
