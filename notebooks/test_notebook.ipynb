# %%
import sqlite3

conn = sqlite3.connect("../data/vivino.db")
cursor = conn.cursor()

with open("../queries/test_queries.sql", "r") as f:
    query = f.read()

cursor.execute(query)
cursor.fetchall()
# Out:
# [('Cabernet Sauvignon', 4.8, 2941, 'Cabernet Sauvignon'),
#  ('Special Selection Cabernet Sauvignon', 4.7, 41236, 'Cabernet Sauvignon'),
#  ('Cabernet Sauvignon (Signature)', 4.6, 13730, 'Cabernet Sauvignon'),
#  ('Cabernet Sauvignon', 4.6, 157944, 'Cabernet Sauvignon'),
#  ('Beckstoffer To Kalon Vineyard Cabernet Sauvignon',
#   4.6,
#   1557,
#   'Cabernet Sauvignon')]
