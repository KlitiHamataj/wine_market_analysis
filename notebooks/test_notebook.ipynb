# %%
import sqlite3

conn = sqlite3.connect("../data/vivino.db")
cursor = conn.cursor()

with open("../queries/test_queries.sql", "r") as f:
    query = f.read()

cursor.execute(query)
cursor.fetchall()
# Out:
# [('Louis Roederer Cristal Brut Champagne (Millésimé) 2002',),
#  ('Louis Roederer Cristal Rosé Brut Champagne (Millésimé) 2002',),
#  ('Louis Roederer Cristal Brut Champagne (Millésimé) 1999',),
#  ('Louis Roederer Cristal Brut Champagne (Millésimé) 2000',),
#  ('Louis Roederer Cristal Brut Champagne (Millésimé) 2008',)]
