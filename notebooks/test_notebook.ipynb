# %%
import sqlite3

conn = sqlite3.connect("../data/vivino.db")
cursor = conn.cursor()  # not cursos() 😄

with open("../queries/test_queries.sql", "r") as f:
    query = f.read()

cursor.execute(query)
print(cursor.fetchall())
# Out:
# [('Allemagne', 2549989, 164533, 4.500000000000001), ('Israël', 150549, 5435, 4.5), ('États-Unis', 12273684, 204060, 4.4905405405405405), ('Moldavie', 13583, 5055, 4.4799999999999995), ('Hongrie', 102235, 16605, 4.472727272727273), ('Afrique du Sud', 269649, 30857, 4.459090909090909), ('Australie', 1022965, 90954, 4.458333333333333), ('France', 5973301, 422503, 4.447129909365562), ('Espagne', 2264396, 102662, 4.4436170212765935), ('Portugal', 1123535, 39847, 4.435714285714287)]
